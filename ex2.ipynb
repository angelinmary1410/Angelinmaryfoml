# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('suv_data - suv_data (1).csv')

# %%
print("first row")
print(data.head())
# Out:
# first row
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
x_col="Age"
y_col="EstimatedSalary"
x=data[[x_col]].values
y=data[y_col].values

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x)
plt.scatter(x,y,color="pink",label="Data points")
plt.plot(x,y_pred,color="yellow",label="Regression line")
plt.xlabel(x_col)
plt.ylabel(y_col)
plt.title("linear")
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data = pd.read_csv('suv_data - suv_data (1).csv')

# %%
x_columns = ['Age', 'EstimatedSalary']  # Replace with your feature columns
y_column = 'Purchased'                       # Replace with your target column


X = data[x_columns].values
y = data[y_column].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
svm_classifier = SVC(kernel='linear')  # Use 'rbf' for non-linear
svm_classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.85
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89        73
#            1       0.97      0.64      0.77        47
#
#     accuracy                           0.85       120
#    macro avg       0.89      0.81      0.83       120
# weighted avg       0.87      0.85      0.84       120
#
# Confusion Matrix:
# [[72  1]
#  [17 30]]
