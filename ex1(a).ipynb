# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
a=pd.read_csv("Iris - Iris.csv")

# %%
sns.barplot(x="Species",y="PetalLengthCm",data=a,color="pink")
plt.xlabel("Species")
plt.ylabel("petalLengthCM")
plt.title("uni-petal")
plt.show()

# %%
# Out:
# Text(0.5, 0, 'Species')

# %%
# Out:
# Text(0, 0.5, 'petalLengthCM')
